# %%
import matplotlib.pyplot as plt
import pandas as pd
 
a=pd.read_csv('/home/ksb/Desktop/vyshnav/Kmeans/myFile0.csv')  
print(a)

 
# print(x)
 
#no traing test required
from sklearn.cluster import KMeans
kmeans=KMeans(init='k-means++',n_clusters=2,random_state=0).fit(x)
p=kmeans.predict(x)

 
 
colors=list(map(lambda x:'#008000' if x==1 else '#00FFFF',p))
plt.scatter(x[:,0],x[:,1],c=colors,marker='*',picker=True)
 
plt.show()
# Out:
#        id    a    b
# 0     100  908   13
# 1     101  176  698
# 2     102  117  877
# 3     103  997  801
# 4     104  956   94
# ..    ...  ...  ...
# 995  1095  476  385
# 996  1096   94  789
# 997  1097  143  240
# 998  1098  963  431
# 999  1099  598  970
#
# [1000 rows x 3 columns]
